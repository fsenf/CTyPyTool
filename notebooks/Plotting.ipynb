# %%
import sys
sys.path.append('../cloud_classifier')

import cloud_classifier

import importlib

importlib.reload(cloud_classifier)
# Out:
# <module 'cloud_classifier' from '/home/squidy/tropos/notebooks/../cloud_classifier/cloud_classifier.py'>

# %%
cc = cloud_classifier.cloud_classifier()
cc.load_project("../classifiers/usable_forest")

# %%
#cc.evaluation_plots(correlation = True)

# %%
#cc.evaluation_plots(probas = True, plot_titles = ["Classifier Certainity", "Random Forest Classifier"], show =False)

# %%
t1 = "../classifiers/usable_tree"
cc.evaluation_plots(comparison = True, cmp_targets = [t1],
    plot_titles = ["Random Forest Classifier", "Tree Classifier"],
    show =False)
# Out:
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200608_0000_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20190906_0100_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200813_0200_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200507_0300_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20190820_0400_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20190409_0500_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200422_0600_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200709_0700_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20190416_0800_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20190722_0900_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200211_1000_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20190112_1100_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20190722_1200_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20190516_1300_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200809_1400_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20190416_1500_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20190326_1600_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20191029_1700_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200428_1800_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200305_1900_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200330_2000_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200418_2100_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200218_2200_ComparisonPlot.png
# Comparison Plot saved at ../classifiers/usable_forest/plots/Comparisons/20200330_2300_ComparisonPlot.png

# %%
georef = "../data/training_data/msevi-medi-georef.nc"
titles = [ "Random Forest Classifier"]
titles_prob = [ "Classifier Certainty","Random Forest Classifier"]
h = 0
for timestamp in cc.timestamps:
    print(timestamp)
    gtrouth = "../data/full_dataset/nwcsaf_msevi-medi-" + timestamp + ".nc"
    pred_forest = "../classifiers/usable_forest/labels/nwcsaf_msevi-medi-" + timestamp + "_predicted.nc"
    
    cc.plot_coocurrence_matrix(pred_forest, gtrouth, normalize = True)
    #cc.plot_multiple(label_files = [pred_forest ], georef_file = georef, truth_file = gtrouth, 
    #             reduce_to_mask = True, plot_titles = titles, hour = h )
    h+=1
# Out:
# 20200608_0000
# Correlation Matrix, without normalization
# 20190906_0100
# Correlation Matrix, without normalization
# 20200813_0200
# Correlation Matrix, without normalization
# 20200507_0300
# Correlation Matrix, without normalization
# 20190820_0400
# Correlation Matrix, without normalization
# 20190409_0500
# Correlation Matrix, without normalization
# 20200422_0600
# Correlation Matrix, without normalization
# 20200709_0700
# Correlation Matrix, without normalization
# 20190416_0800
# Correlation Matrix, without normalization
# 20190722_0900
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6972/2548548266.py in <module>
#       8     pred_forest = "../classifiers/usable_forest/labels/nwcsaf_msevi-medi-" + timestamp + "_predicted.nc"
#       9
# ---> 10     cc.plot_coocurrence_matrix(pred_forest, gtrouth, normalize = False)
#      11     #cc.plot_multiple(label_files = [pred_forest ], georef_file = georef, truth_file = gtrouth,
#      12     #             reduce_to_mask = True, plot_titles = titles, hour = h )
#
# ~/tropos/notebooks/../cloud_classifier/data_handler.py in plot_coocurrence_matrix(self, label_file, truth_file, normalize)
#     579         l_data,_,_ = self.get_plotable_data(data_file = label_file, reduce_to_mask = True)
#     580
# --> 581         cm = conf.confusion_matrix(l_data, t_data)
#     582
#     583         _, ct_indices, ct_labels = ex.definde_NWCSAF_variables()
#
# ~/tropos/notebooks/../cloud_classifier/tools/confusion.py in confusion_matrix(label_data, ground_truth, missing_indices)
#      86         cm = np.zeros([len(ct_indices), len(ct_indices)],dtype = int)
#      87         for  i, value in enumerate(d2):
# ---> 88                 for j, label in enumerate(ct_indices):
#      89                         if d1[i] == label:
#      90                                 cm[ct_indices.index(value)][j] += 1
#
# KeyboardInterrupt:

# %%
georef = "../data/training_data/msevi-medi-georef.nc"
titles = [ "Random Forest Classifier"]
titles_prob = [ "Classifier Certainty","Random Forest Classifier"]
h = 0
for timestamp in cc.timestamps:
    print(timestamp)
    gtrouth = "../data/full_dataset/nwcsaf_msevi-medi-" + timestamp + ".nc"
    pred_tree = "../classifiers/usable_tree/labels/nwcsaf_msevi-medi-" + timestamp + "_predicted.nc"
    pred_forest = "../classifiers/usable_forest/labels/nwcsaf_msevi-medi-" + timestamp + "_predicted.nc"
    
    cc.plot_probas(label_file = pred_forest , georef_file = georef, truth_file = gtrouth, 
                 reduce_to_mask = True, plot_titles = titles_prob, hour = h )
    
    #cc.plot_multiple(label_files = [pred_forest ], georef_file = georef, truth_file = gtrouth, 
    #             reduce_to_mask = True, plot_titles = titles, hour = h )
    h+=1
