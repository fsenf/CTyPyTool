# %%
import sys
sys.path.append('../cloud_classifier')

import cloud_classifier

import importlib

importlib.reload(cloud_classifier)
# Out:
# <module 'cloud_classifier' from '/home/squidy/tropos/notebooks/../cloud_classifier/cloud_classifier.py'>

# %%
filename = "../data/input_data/labels/nwcsaf_msevi-medi-20190316_0900.nc"
georef = "../data/training_data/msevi-medi-georef.nc"
cc = cloud_classifier.cloud_classifier()

# %%
cc.check_nwcsaf_version(filename = "../data/input_data/labels/nwcsaf_msevi-medi-20190316_0900.nc", verbose = True)
# Out:
# The cloud type data is coded after the old (2013) standard
# 'v2013'

# %%
cc.plot_labels(data_file = filename, georef_file = georef, reduce_to_mask = True )

# %%
cc.plot_labels(data_file = filename, georef_file = georef, reduce_to_mask = False )

# %%
import xarray as xr
mask = xr.open_dataset("../data/input_data/labels/nwcsaf_msevi-medi-20190316_0900.nc")
for key in mask:
    print(key)
# Out:
# time_bnds
# ct
# cph
# platform
# lon0

# %%
# Out:
# <xarray.DataArray 'cph' (time: 1, y: 500, x: 1300)>
# [650000 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2019-03-16T09:00:00
#   * x        (x) uint16 1562 1563 1564 1565 1566 ... 2857 2858 2859 2860 2861
#   * y        (y) uint16 362 363 364 365 366 367 368 ... 856 857 858 859 860 861
# Attributes:
#     valid_range:    [1 3]
#     long_name:      Cloud Phase
#     standard_name:  thermodynamic_phase_of_cloud_water_particles_at_cloud_top
#     flag_values:    [1 2 3]
#     flag_meanings:  liquid ice undefined
