# %%
import sys
sys.path.append('../cloud_classifier')

import cloud_classifier

import importlib

importlib.reload(cloud_classifier)
# Out:
# <module 'cloud_classifier' from '/home/squidy/tropos/notebooks/../cloud_classifier/cloud_classifier.py'>

# %%
cc = cloud_classifier.cloud_classifier()
cc.load_project("../classifiers/usable_forest")

# %%
cc.get_overallCoocurrence(show = True)
# Out:
# Correlation Matrix saved at plots/Coocurrence ../classifiers/usable_forest/plots/Coocurrence/Overall_CoocurrenceMatrix.png

# %%
#cc.create_evaluation_plots(correlation = True)
# Out:
# Correlation Matrix saved at plots/Coocurrence ../classifiers/usable_tree/plots/Coocurrence/20200608_0000_CoocurrenceMatrix.png
# Correlation Matrix saved at plots/Coocurrence ../classifiers/usable_tree/plots/Coocurrence/20190906_0100_CoocurrenceMatrix.png
# Correlation Matrix saved at plots/Coocurrence ../classifiers/usable_tree/plots/Coocurrence/20200813_0200_CoocurrenceMatrix.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17174/1546379174.py in <module>
# ----> 1 cc.create_evaluation_plots(correlation = True)
#
# ~/tropos/notebooks/../cloud_classifier/cloud_classifier.py in create_evaluation_plots(self, correlation, probas, comparison, cmp_targets, plot_titles, show, verbose)
#     189             timestamp = self.eval_timestamps[i]
#     190             if(correlation):
# --> 191                 self.save_coorMatrix(label_file = label_file, truth_file = truth_file, timestamp = timestamp,
#     192                     verbose=verbose, show = show)
#     193             if(comparison):
#
# ~/tropos/notebooks/../cloud_classifier/cloud_classifier.py in save_coorMatrix(self, label_file, truth_file, label_data, truth_data, timestamp, filename, normalize, verbose, show)
#     275         filename = os.path.join(self.project_path, path, filename)
#     276
# --> 277         conf.plot_coocurrence_matrix(label_data, truth_data, normalize=normalize, save_file = filename)
#     278         if (verbose):
#     279             print("Correlation Matrix saved at " + path, filename)
#
# ~/tropos/notebooks/../cloud_classifier/tools/confusion.py in plot_coocurrence_matrix(label_data, truth_data, normalize, title, cmap, missing_indices, rate, save_file, show)
#      25     """
#      26
# ---> 27     cm = confusion_matrix(label_data, truth_data)
#      28     fig = plt.figure(figsize=(12,12))
#      29     fig.patch.set_alpha(1)
#
# ~/tropos/notebooks/../cloud_classifier/tools/confusion.py in confusion_matrix(label_data, ground_truth, missing_indices)
#     106     for  i, value in enumerate(d2):
#     107         for j, label in enumerate(ct_indices):
# --> 108             if d1[i] == label:
#     109                 cm[ct_indices.index(value)][j] += 1
#     110     return cm
#
# KeyboardInterrupt:

# %%
#cc.create_evaluation_plots(probas = True, plot_titles = ["Classifier Certainity", "Tree Classifier"], show =False)

# %%
t1 = "../classifiers/usable_tree"
cc.create_evaluation_plots(comparison = True, cmp_targets = [],
    plot_titles = ["Tree Classifier"],
    show =True)
# Out:
# Comparison Plot saved at ../classifiers/usable_tree/plots/Comparisons/20200608_0000_ComparisonPlot.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17174/2867884975.py in <module>
#       1 t1 = "../classifiers/usable_tree"
# ----> 2 cc.create_evaluation_plots(comparison = True, cmp_targets = [],
#       3     plot_titles = ["Tree Classifier"],
#       4     show =True)
#
# ~/tropos/notebooks/../cloud_classifier/cloud_classifier.py in create_evaluation_plots(self, correlation, probas, comparison, cmp_targets, plot_titles, show, verbose)
#     192                     verbose=verbose, show = show)
#     193             if(comparison):
# --> 194                 self.save_comparePlot(label_file = label_file, truth_file = truth_file, timestamp = timestamp,
#     195                     compare_projects =cmp_targets, plot_titles=plot_titles,verbose=verbose, show = show)
#     196             if(probas):
#
# ~/tropos/notebooks/../cloud_classifier/cloud_classifier.py in save_comparePlot(self, label_file, truth_file, timestamp, compare_projects, plot_titles, verbose, show)
#     229         filename = timestamp + "_ComparisonPlot.png"
#     230         path = os.path.join(self.project_path, path, filename)
# --> 231         self.plot_multiple(all_files, truth_file, georef_file = self.georef_file, reduce_to_mask = True,
#     232             plot_titles = plot_titles, hour = hour, save_file = path, show = show)
#     233         if (verbose):
#
# ~/tropos/notebooks/../cloud_classifier/data_handler.py in plot_multiple(self, label_files, truth_file, georef_file, reduce_to_mask, plot_titles, hour, save_file, show)
#     531             plt.savefig(save_file, transparent=False)
#     532         if(show):
# --> 533             plt.show()
#     534         plt.close()
#     535
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     376     """
#     377     _warn_if_gui_out_of_main_thread()
# --> 378     return _backend_mod.show(*args, **kwargs)
#     379
#     380
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     251
#     252     if 'png' in formats:
# --> 253         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     254     if 'retina' in formats or 'png2x' in formats:
#     255         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     135         FigureCanvasBase(fig)
#     136
# --> 137     fig.canvas.print_figure(bytes_io, **kw)
#     138     data = bytes_io.getvalue()
#     139     if fmt == 'svg':
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     506             *metadata*, including the default 'Software' key.
#     507         """
# --> 508         FigureCanvasAgg.draw(self)
#     509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2788
#    2789             self.patch.draw(renderer)
# -> 2790             mimage._draw_list_compositing_images(
#    2791                 renderer, self, artists, self.suppressComposite)
#    2792
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py in draw(self, renderer, **kwargs)
#     477         self._done_img_factory = True
#     478
# --> 479         return matplotlib.axes.Axes.draw(self, renderer=renderer, **kwargs)
#     480
#     481     def _update_title_position(self, renderer):
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2919             renderer.stop_rasterizing()
#    2920
# -> 2921         mimage._draw_list_compositing_images(renderer, self, artists)
#    2922
#    2923         renderer.close_group('axes')
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/collections.py in draw(self, renderer)
#    2110         if not transform.is_affine:
#    2111             coordinates = self._coordinates.reshape((-1, 2))
# -> 2112             coordinates = transform.transform(coordinates)
#    2113             coordinates = coordinates.reshape(self._coordinates.shape)
#    2114             transform = transforms.IdentityTransform()
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/transforms.py in transform(self, values)
#    1468
#    1469         # Transform the values
# -> 1470         res = self.transform_affine(self.transform_non_affine(values))
#    1471
#    1472         # Convert the result back to the shape of the input values.
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/matplotlib/transforms.py in transform_non_affine(self, points)
#    2384             return points
#    2385         elif not self._a.is_affine and self._b.is_affine:
# -> 2386             return self._a.transform_non_affine(points)
#    2387         else:
#    2388             return self._b.transform_non_affine(
#
# ~/.local/share/virtualenvs/tropos-Ssyp9URO/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py in transform_non_affine(self, xy)
#     142         prj = self.target_projection
#     143         if isinstance(xy, np.ndarray):
# --> 144             return prj.transform_points(self.source_projection,
#     145                                         xy[:, 0], xy[:, 1])[:, 0:2]
#     146         else:
#
# KeyboardInterrupt:

# %%
georef = "../data/training_data/msevi-medi-georef.nc"
titles = [ "Random Forest Classifier"]
titles_prob = [ "Classifier Certainty","Random Forest Classifier"]
h = 0
for timestamp in cc.timestamps:
    print(timestamp)
    gtrouth = "../data/full_dataset/nwcsaf_msevi-medi-" + timestamp + ".nc"
    pred_forest = "../classifiers/usable_forest/labels/nwcsaf_msevi-medi-" + timestamp + "_predicted.nc"
    
    cc.plot_coocurrence_matrix(pred_forest, gtrouth, normalize = True)
    #cc.plot_multiple(label_files = [pred_forest ], georef_file = georef, truth_file = gtrouth, 
    #             reduce_to_mask = True, plot_titles = titles, hour = h )
    h+=1
# Out:
# 20200608_0000
# Correlation Matrix, without normalization
# 20190906_0100
# Correlation Matrix, without normalization
# 20200813_0200
# Correlation Matrix, without normalization
# 20200507_0300
# Correlation Matrix, without normalization
# 20190820_0400
# Correlation Matrix, without normalization
# 20190409_0500
# Correlation Matrix, without normalization
# 20200422_0600
# Correlation Matrix, without normalization
# 20200709_0700
# Correlation Matrix, without normalization
# 20190416_0800
# Correlation Matrix, without normalization
# 20190722_0900
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6972/2548548266.py in <module>
#       8     pred_forest = "../classifiers/usable_forest/labels/nwcsaf_msevi-medi-" + timestamp + "_predicted.nc"
#       9
# ---> 10     cc.plot_coocurrence_matrix(pred_forest, gtrouth, normalize = False)
#      11     #cc.plot_multiple(label_files = [pred_forest ], georef_file = georef, truth_file = gtrouth,
#      12     #             reduce_to_mask = True, plot_titles = titles, hour = h )
#
# ~/tropos/notebooks/../cloud_classifier/data_handler.py in plot_coocurrence_matrix(self, label_file, truth_file, normalize)
#     579         l_data,_,_ = self.get_plotable_data(data_file = label_file, reduce_to_mask = True)
#     580
# --> 581         cm = conf.confusion_matrix(l_data, t_data)
#     582
#     583         _, ct_indices, ct_labels = ex.definde_NWCSAF_variables()
#
# ~/tropos/notebooks/../cloud_classifier/tools/confusion.py in confusion_matrix(label_data, ground_truth, missing_indices)
#      86         cm = np.zeros([len(ct_indices), len(ct_indices)],dtype = int)
#      87         for  i, value in enumerate(d2):
# ---> 88                 for j, label in enumerate(ct_indices):
#      89                         if d1[i] == label:
#      90                                 cm[ct_indices.index(value)][j] += 1
#
# KeyboardInterrupt:

# %%
georef = "../data/training_data/msevi-medi-georef.nc"
titles = [ "Random Forest Classifier"]
titles_prob = [ "Classifier Certainty","Random Forest Classifier"]
h = 0
for timestamp in cc.timestamps:
    print(timestamp)
    gtrouth = "../data/full_dataset/nwcsaf_msevi-medi-" + timestamp + ".nc"
    pred_tree = "../classifiers/usable_tree/labels/nwcsaf_msevi-medi-" + timestamp + "_predicted.nc"
    pred_forest = "../classifiers/usable_forest/labels/nwcsaf_msevi-medi-" + timestamp + "_predicted.nc"
    
    cc.plot_probas(label_file = pred_forest , georef_file = georef, truth_file = gtrouth, 
                 reduce_to_mask = True, plot_titles = titles_prob, hour = h )
    
    #cc.plot_multiple(label_files = [pred_forest ], georef_file = georef, truth_file = gtrouth, 
    #             reduce_to_mask = True, plot_titles = titles, hour = h )
    h+=1

# %%
a = None
str(a) + ""
# Out:
# 'None'

# %%
print("a'v'")
# Out:
# a'v'
